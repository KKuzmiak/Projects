# %% [markdown]
# ####  Automated report
#
# The goal is to generate a sales report at the end of each month for the current month.
# The user adds a new file with data to a monthly data folder and then runs this Jupyter notebook. The code recognises the lates file and uses the data from this file to generate report for the current month, basing on the code written in the Template-report notebook. Thanks to this, it is easier and faster to gerate and save mothly reports.

# %%
# Import libraries
import papermill as pm
import glob
import os

# %%
# Searching for the latest file
list_of_files = glob.glob('/home/kinga/python/Papermill-report/*.xlsx') # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
latest_file=latest_file.split('.')[0].split('/')[-1]
latest_file
# Out:
# 'Data_August'

# %%
# Executing Papermill
pm.execute_notebook(
   '/home/kinga/python/Papermill-report/Template-Report.ipynb', # the name of the file what we will use as a base to run our notebook- the one with parameters
   'Report_'+f'{latest_file}.ipynb',# the name of the new notebook that we will generate with the new arguments.
   parameters={'filename':f'{latest_file}.xlsx'}, nest_asyncio=True # a dictionary of the variables that we want to insert into
    #our template, in this case, the filename variable, that will now point to our August sales report
)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Executing', max=17.0, style=ProgressStyle(description_wid…
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:50.360927',
#      'end_time': '2020-08-20T19:52:52.971349',
#      'duration': 2.610422,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-08-20T19:52:50.393463Z',
#      'iopub.execute_input': '2020-08-20T19:52:50.394410Z',
#      'shell.execute_reply': '2020-08-20T19:52:52.970327Z',
#      'iopub.status.idle': '2020-08-20T19:52:52.971200Z'}},
#    'outputs': [],
#    'source': '# Import libraries\nimport pandas as pd\nimport random\nimport datetime\nimport numpy as np\nimport dash\nimport dash_core_components as dcc\nimport dash_html_components as html\nfrom dash.dependencies import Input, Output\nimport plotly.graph_objs as go\nimport plotly.offline as pyo\nimport calendar'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:52.989990',
#      'end_time': '2020-08-20T19:52:53.023074',
#      'duration': 0.033084,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-08-20T19:52:53.018600Z',
#      'iopub.execute_input': '2020-08-20T19:52:53.020256Z',
#      'iopub.status.idle': '2020-08-20T19:52:53.021922Z',
#      'shell.execute_reply': '2020-08-20T19:52:53.022879Z'}},
#    'outputs': [],
#    'source': "filename='/home/kinga/python/Papermill-report/Data_August.xlsx'"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:53.042172',
#      'end_time': '2020-08-20T19:52:53.074511',
#      'duration': 0.032339,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-08-20T19:52:53.070733Z',
#      'iopub.execute_input': '2020-08-20T19:52:53.072010Z',
#      'iopub.status.idle': '2020-08-20T19:52:53.073685Z',
#      'shell.execute_reply': '2020-08-20T19:52:53.074334Z'}},
#    'execution_count': 3,
#    'source': '# Parameters\nfilename = "Data_August.xlsx"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:53.093914',
#      'end_time': '2020-08-20T19:52:53.422634',
#      'duration': 0.32872,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-08-20T19:52:53.123744Z',
#      'iopub.execute_input': '2020-08-20T19:52:53.125485Z',
#      'shell.execute_reply': '2020-08-20T19:52:53.421645Z',
#      'iopub.status.idle': '2020-08-20T19:52:53.422502Z'}},
#    'outputs': [],
#    'source': 'df=pd.read_excel(filename)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:53.440207',
#      'end_time': '2020-08-20T19:52:53.458055',
#      'duration': 0.017848,
#      'status': 'completed'}},
#    'source': '#### Report  August'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:53.492400',
#      'end_time': '2020-08-20T19:52:53.531301',
#      'duration': 0.038901,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-08-20T19:52:53.523227Z',
#      'iopub.execute_input': '2020-08-20T19:52:53.524339Z',
#      'shell.execute_reply': '2020-08-20T19:52:53.528989Z',
#      'iopub.status.idle': '2020-08-20T19:52:53.530852Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'current month is: August , current year is: 2020\n'}],
#    'source': "# report is generated for the current month, so I have to find out what the cureent month is\ncurrent_date=datetime.date.today()\ncurrent_month=current_date.month\nmonth_name=calendar.month_name[current_month]\ncurrent_year=current_date.year\nprint ('current month is:', month_name, ', current year is:', current_year)\n"},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'scrolled': True,
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:53.550909',
#      'end_time': '2020-08-20T19:52:53.622905',
#      'duration': 0.071996,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-08-20T19:52:53.578039Z',
#      'iopub.execute_input': '2020-08-20T19:52:53.579277Z',
#      'shell.execute_reply': '2020-08-20T19:52:53.621970Z',
#      'iopub.status.idle': '2020-08-20T19:52:53.622773Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '    Unnamed: 0      Name       Date  Quantity_prod_A  Quantity_prod_B  \\\n1            1     Filip 2020-08-16                9                1   \n5            5  Karolina 2020-08-28                3                8   \n12          12     Filip 2020-08-11                5                4   \n20          20      Adam 2020-08-28                2                1   \n25          25  Karolina 2020-08-10                4                6   \n\n    Quantity_prod_C  Total  \n1                 4     14  \n5                 7     18  \n12                4     13  \n20                8     11  \n25                9     19  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>Name</th>\n      <th>Date</th>\n      <th>Quantity_prod_A</th>\n      <th>Quantity_prod_B</th>\n      <th>Quantity_prod_C</th>\n      <th>Total</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>Filip</td>\n      <td>2020-08-16</td>\n      <td>9</td>\n      <td>1</td>\n      <td>4</td>\n      <td>14</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>5</td>\n      <td>Karolina</td>\n      <td>2020-08-28</td>\n      <td>3</td>\n      <td>8</td>\n      <td>7</td>\n      <td>18</td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>12</td>\n      <td>Filip</td>\n      <td>2020-08-11</td>\n      <td>5</td>\n      <td>4</td>\n      <td>4</td>\n      <td>13</td>\n    </tr>\n    <tr>\n      <th>20</th>\n      <td>20</td>\n      <td>Adam</td>\n      <td>2020-08-28</td>\n      <td>2</td>\n      <td>1</td>\n      <td>8</td>\n      <td>11</td>\n    </tr>\n    <tr>\n      <th>25</th>\n      <td>25</td>\n      <td>Karolina</td>\n      <td>2020-08-10</td>\n      <td>4</td>\n      <td>6</td>\n      <td>9</td>\n      <td>19</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 6}],
#    'source': "# selecting data for the current month \ndf_current=df[pd.to_datetime(df['Date']).dt.month == current_month]\ndf_current.head()"},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'scrolled': True,
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:53.637843',
#      'end_time': '2020-08-20T19:52:53.797302',
#      'duration': 0.159459,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-08-20T19:52:53.673692Z',
#      'iopub.execute_input': '2020-08-20T19:52:53.674560Z',
#      'shell.execute_reply': '2020-08-20T19:52:53.796304Z',
#      'iopub.status.idle': '2020-08-20T19:52:53.797165Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '       Quantity_prod_A  Quantity_prod_B  Quantity_prod_C      Total\ncount       332.000000       332.000000       332.000000  332.00000\nmean          5.548193         5.737952         5.183735   16.46988\nstd           2.882507         2.795228         2.883326    5.15989\nmin           1.000000         1.000000         1.000000    4.00000\n25%           3.000000         3.750000         3.000000   13.00000\n50%           6.000000         6.000000         5.000000   17.00000\n75%           8.000000         8.000000         8.000000   20.00000\nmax          10.000000        10.000000        10.000000   29.00000',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Quantity_prod_A</th>\n      <th>Quantity_prod_B</th>\n      <th>Quantity_prod_C</th>\n      <th>Total</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>count</th>\n      <td>332.000000</td>\n      <td>332.000000</td>\n      <td>332.000000</td>\n      <td>332.00000</td>\n    </tr>\n    <tr>\n      <th>mean</th>\n      <td>5.548193</td>\n      <td>5.737952</td>\n      <td>5.183735</td>\n      <td>16.46988</td>\n    </tr>\n    <tr>\n      <th>std</th>\n      <td>2.882507</td>\n      <td>2.795228</td>\n      <td>2.883326</td>\n      <td>5.15989</td>\n    </tr>\n    <tr>\n      <th>min</th>\n      <td>1.000000</td>\n      <td>1.000000</td>\n      <td>1.000000</td>\n      <td>4.00000</td>\n    </tr>\n    <tr>\n      <th>25%</th>\n      <td>3.000000</td>\n      <td>3.750000</td>\n      <td>3.000000</td>\n      <td>13.00000</td>\n    </tr>\n    <tr>\n      <th>50%</th>\n      <td>6.000000</td>\n      <td>6.000000</td>\n      <td>5.000000</td>\n      <td>17.00000</td>\n    </tr>\n    <tr>\n      <th>75%</th>\n      <td>8.000000</td>\n      <td>8.000000</td>\n      <td>8.000000</td>\n      <td>20.00000</td>\n    </tr>\n    <tr>\n      <th>max</th>\n      <td>10.000000</td>\n      <td>10.000000</td>\n      <td>10.000000</td>\n      <td>29.00000</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 7}],
#    'source': "# quick statistical analysis\nstatistic=df_current.describe().iloc[:,1:]\n# results are saved in the excel file \nstatistic.to_excel('/home/kinga/python/Papermill-report/monthly_reports/'+month_name+'-statistic.xlsx')\nstatistic"},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:53.815325',
#      'end_time': '2020-08-20T19:52:53.917314',
#      'duration': 0.101989,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-08-20T19:52:53.854471Z',
#      'iopub.execute_input': '2020-08-20T19:52:53.855327Z',
#      'iopub.status.idle': '2020-08-20T19:52:53.916354Z',
#      'shell.execute_reply': '2020-08-20T19:52:53.917134Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '        Name  Quantity_prod_A  Quantity_prod_B  Quantity_prod_C  Total\n0       Adam              361              349              337   1047\n1      Filip              475              496              458   1429\n2   Karolina              272              313              251    836\n3  Katarzyna              391              405              357   1153\n4     Robert              343              342              318   1003\n5        All             1842             1905             1721   5468',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Name</th>\n      <th>Quantity_prod_A</th>\n      <th>Quantity_prod_B</th>\n      <th>Quantity_prod_C</th>\n      <th>Total</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Adam</td>\n      <td>361</td>\n      <td>349</td>\n      <td>337</td>\n      <td>1047</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Filip</td>\n      <td>475</td>\n      <td>496</td>\n      <td>458</td>\n      <td>1429</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Karolina</td>\n      <td>272</td>\n      <td>313</td>\n      <td>251</td>\n      <td>836</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Katarzyna</td>\n      <td>391</td>\n      <td>405</td>\n      <td>357</td>\n      <td>1153</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Robert</td>\n      <td>343</td>\n      <td>342</td>\n      <td>318</td>\n      <td>1003</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>All</td>\n      <td>1842</td>\n      <td>1905</td>\n      <td>1721</td>\n      <td>5468</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 8}],
#    'source': '# sales by Representative in the current month \nsales_by_rep=pd.pivot_table(df_current, index=\'Name\', values=["Quantity_prod_A", "Quantity_prod_B", "Quantity_prod_C",\n                            "Total"], aggfunc=np.sum, margins=True)\nsales_by_rep=pd.DataFrame(sales_by_rep.to_records())\n# results are saved in the excel file \nsales_by_rep.to_excel(\'/home/kinga/python/Papermill-report/monthly_reports/\'+month_name+\'-sales-by-rep.xlsx\')\nsales_by_rep'},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:53.936528',
#      'end_time': '2020-08-20T19:52:56.123031',
#      'duration': 2.186503,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-08-20T19:52:53.970392Z',
#      'iopub.execute_input': '2020-08-20T19:52:53.971463Z',
#      'iopub.status.idle': '2020-08-20T19:52:56.122024Z',
#      'shell.execute_reply': '2020-08-20T19:52:56.122840Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'Sales_by_rep_August.html'"},
#      'execution_count': 9}],
#    'source': "# Sales by Representative on the bar chart. Results are save as html file\ndata=[]\n\nproducts=sales_by_rep.columns[1:4] \n\nfor prod in products:\n    trace=go.Bar(x=sales_by_rep['Name'].iloc[:-1], y=sales_by_rep[prod],text=sales_by_rep[prod],\n                 textposition='auto',orientation='v', name=prod)\n    data.append(trace)\n    \nlayout=go.Layout(title='Sales by Representative in '+month_name, barmode='group', hovermode='closest',\n                 bargroupgap=0.1,xaxis={'title': 'Representative' }, yaxis={'title': 'Sales' })\n\n\n\nfig=go.Figure(data=data, layout=layout)\npyo.plot(fig, filename='Sales_by_rep_'+month_name+'.html')"},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:56.174078',
#      'end_time': '2020-08-20T19:52:56.226274',
#      'duration': 0.052196,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': ''},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:56.286874',
#      'end_time': '2020-08-20T19:52:56.337398',
#      'duration': 0.050524,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': ''},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:56.370963',
#      'end_time': '2020-08-20T19:52:56.401074',
#      'duration': 0.030111,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': ''},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:56.429157',
#      'end_time': '2020-08-20T19:52:56.454396',
#      'duration': 0.025239,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': ''},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:56.482443',
#      'end_time': '2020-08-20T19:52:56.505369',
#      'duration': 0.022926,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': ''},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:56.541456',
#      'end_time': '2020-08-20T19:52:56.569070',
#      'duration': 0.027614,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': ''},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-20T19:52:56.594256',
#      'end_time': '2020-08-20T19:52:56.623119',
#      'duration': 0.028863,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': ''}],
#  'metadata': {'celltoolbar': 'Tags',
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.4',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {'filename': 'Data_August.xlsx'},
#    'environment_variables': {},
#    'version': '2.1.1',
#    'input_path': '/home/kinga/python/Papermill-report/Template-Report.ipynb',
#    'output_path': 'Report_Data_August.ipynb',
#    'start_time': '2020-08-20T19:52:49.323671',
#    'end_time': '2020-08-20T19:52:56.775838',
#    'duration': 7.452167,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 4}
